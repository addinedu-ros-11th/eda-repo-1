# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 태양풍 데이터 전처리
#
# - 날짜 기준으로 데이터 전처리 : 시간 기준의 데이터를 날짜별 평균으로 처리
#
#
# - column별 데이터의 의미
#
#     - date: 데이터가 관측된 날짜와 시간입니다.
#
#     - bt: 자기장의 총 세기 (Total Magnetic Field Strength) 입니다. 단위는 보통 나노테슬라(nT)를 사용하며, 이 값이 클수록 자기장 자체가 강하다는 의미입니다.
#
#     - theta_gse / phi_gse: GSE 좌표계를 기준으로 자기장 벡터의 방향을 나타내는 각도입니다.
#
#     - theta_gse (세타): 위도 각도. Z축(황도면에 수직인 방향)과의 각도입니다.
#
#     - phi_gse (파이): 경도 각도. X축(지구-태양 방향)에서 XY평면을 따라 측정한 각도입니다.
#
#     - theta_gsm / phi_gsm: GSM 좌표계를 기준으로 자기장 벡터의 방향을 나타내는 각도입니다.
#
#     - theta_gsm (세타): 위도 각도.
#
#     - phi_gsm (파이): 경도 각도.

# %%
# mag_org.csv 파일 불러오기
df_mag = pd.read_csv('/home/roni/dev_ws/ufo_eda/data/mag_org.csv')

# %%
df_mag.dtypes
# 데이터 타입 확인 -> date column 을 datetime 타입으로 변경 필요
# Out:
# date          object
# bt           float64
# theta_gse    float64
# phi_gse      float64
# theta_gsm    float64
# phi_gsm      float64
# dtype: object

# %%
# date column 을 날짜와 시간으로 분리
# 나중에 날짜 기준으로 groupby하여 평균값으로 날짜 기준 데이터로 만들기 위함

list_date = []
list_time = []

for date in df_mag['date']:
    only_date = date.split(' ')[0]
    only_time = date.split(' ')[1]
    
    list_date.append(only_date)
    list_time.append(only_time)
    
    
df_mag['date'] = list_date
df_mag['time'] = list_time

# %%
df_mag['date'] = pd.to_datetime(df_mag['date'])
df_mag['time'] = pd.to_datetime(df_mag['time'])
# Out:
# /tmp/ipykernel_21157/1751772897.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_mag['time'] = pd.to_datetime(df_mag['time'])

# %%
# 날짜 기준으로 평균을 내서 날짜 기준 데이터로 변경
df_mag = df_mag.groupby(df_mag['date'], as_index = False).mean(numeric_only = True)

# %%
df_mag = df_mag.drop(columns = 'time')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df_mag = df_mag.drop(columns = 'time')
#
# File ~/venv/ufo_eda/lib/python3.12/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~/venv/ufo_eda/lib/python3.12/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~/venv/ufo_eda/lib/python3.12/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~/venv/ufo_eda/lib/python3.12/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['time'] not found in axis"

# %%
df_mag
# Out:
#            date         bt  theta_gse     phi_gse  theta_gsm     phi_gsm
# 0    2018-11-08   4.201618   1.639833  124.072722  -7.467917  126.339301
# 1    2018-11-09   5.654160 -18.319604  203.009965 -18.635729  221.180469
# 2    2018-11-10   8.013868   1.358437  286.612578  10.584306  283.317374
# 3    2018-11-11   4.885163   5.908899  279.866334  13.607603  272.854985
# 4    2018-11-12   4.114291  -4.749343  231.083344  -0.697394  225.140376
# ...         ...        ...        ...         ...        ...         ...
# 1626 2023-11-05  19.863812  -1.501554  220.622625   6.811093  232.189722
# 1627 2023-11-06  11.346820  -9.671675  241.561084  -1.399630  237.211461
# 1628 2023-11-07   6.045146   9.152118  206.763660  10.159028  193.063896
# 1629 2023-11-08   5.563336  12.647262  258.011492  19.430773  232.937846
# 1630 2023-11-09   4.035942  -0.494623  269.740072  10.117246  265.152613
#
# [1631 rows x 6 columns]

# %% [markdown]
# #### 태양풍 데이터 데이터 베이스 저장

# %%
import mysql.connector
import os
from dotenv import load_dotenv
from mysql.connector import Error

# %%
load_dotenv()
aws_db_ufo_pw = os.getenv('aws_db_ufo_pw')
aws_host_ufo = os.getenv('aws_host_ufo')

# %%
remote = mysql.connector.connect(
    host = aws_host_ufo,
    user = 'EDA',
    port = 3306,  # default 는 3306
    password = aws_db_ufo_pw,
    database = 'Frisbee'

)

cursor = remote.cursor()

# %%
cursor.close()
# Out:
# True

# %%
df_mag
# Out:
#            date         bt  theta_gse     phi_gse  theta_gsm     phi_gsm
# 0    2018-11-08   4.201618   1.639833  124.072722  -7.467917  126.339301
# 1    2018-11-09   5.654160 -18.319604  203.009965 -18.635729  221.180469
# 2    2018-11-10   8.013868   1.358437  286.612578  10.584306  283.317374
# 3    2018-11-11   4.885163   5.908899  279.866334  13.607603  272.854985
# 4    2018-11-12   4.114291  -4.749343  231.083344  -0.697394  225.140376
# ...         ...        ...        ...         ...        ...         ...
# 1626 2023-11-05  19.863812  -1.501554  220.622625   6.811093  232.189722
# 1627 2023-11-06  11.346820  -9.671675  241.561084  -1.399630  237.211461
# 1628 2023-11-07   6.045146   9.152118  206.763660  10.159028  193.063896
# 1629 2023-11-08   5.563336  12.647262  258.011492  19.430773  232.937846
# 1630 2023-11-09   4.035942  -0.494623  269.740072  10.117246  265.152613
#
# [1631 rows x 6 columns]

# %%
table_name = 'mag_strength_data'

query_create_table = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            date DATETIME,
            bt FLOAT,
            theta_gse FLOAT,
            phi_gse FLOAT,
            theta_gsm FLOAT,
            phi_gsm FLOAT
        )
        """
        
cursor.execute(query_create_table)
remote.commit()
print(f"테이블 '{table_name}'이(가) 성공적으로 생성되었거나 이미 존재합니다.")
# Out:
# 테이블 'mag_strength_data'이(가) 성공적으로 생성되었거나 이미 존재합니다.

# %%
for idx, row in df_mag.iterrows():

    query = f"""
    INSERT INTO {table_name} (date, bt, theta_gse, phi_gse, theta_gsm, phi_gsm)
    VALUES (%s,%s,%s,%s,%s,%s)
    """

    cursor.execute(query, tuple(row))
    
    
remote.commit()
print(f"{cursor.rowcount} 개의 ROW가 {table_name} 테이블에 성공적으로 삽입 되었습니다")
# Out:
# 1 개의 ROW가 mag_strength_data 테이블에 성공적으로 삽입 되었습니다

# %%
df_mag.to_csv('/home/roni/dev_ws/ufo_eda/data/mag_org_pp.csv')

# %% [markdown]
# ### UFO data Preprocess

# %%
# ufo_data load
df_ufo = pd.read_csv('/home/roni/dev_ws/ufo_eda/data/ufo/complete.csv', on_bad_lines='skip')
# Out:
# /tmp/ipykernel_21157/1118005436.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ufo = pd.read_csv('/home/roni/dev_ws/ufo_eda/data/ufo/complete.csv', on_bad_lines='skip')

# %%
# data type 확인
df_ufo.dtypes
# Out:
# datetime                 object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
# datetime 날짜와 시간 분리
list_date = []
list_time = []
for dt in df_ufo['datetime']:
    only_date = dt.split(' ')[0]
    only_time = dt.split(' ')[1]
    
    list_date.append(only_date)
    list_time.append(only_time)
    
# 데이터 프레임에 date 컬럼과 time 컬럼을 만들어서 나누어진 데이터 적용
df_ufo_date_splited = df_ufo
df_ufo_date_splited['date'] = list_date
df_ufo_date_splited['time'] = list_time

# %%
new_col = ['date', 'time', 'datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)', 'duration (hours/min)', 'comments', 'date posted', 'latitude', 'longitude']

# %%
# 컬럼 순서 바꾸기

new_col = ['date', 'time', 'datetime', 'city', 'state', 'country',
        'shape', 'duration (seconds)', 'duration (hours/min)', 
        'comments', 'date posted', 'latitude', 'longitude']

df_ufo_f = df_ufo_date_splited[new_col]

# 기존 datetime 컬럼 제거
df_ufo_f = df_ufo_f.drop(columns= 'datetime')

# %%
# 국가 미국만 추철
df_ufo_us = df_ufo_f.loc[df_ufo_f['country'] == 'us']
df_ufo_us.reset_index(drop = True)
# Out:
#              date   time            city state country     shape  \
# 0      10/10/1949  20:30      san marcos    tx      us  cylinder
# 1      10/10/1956  21:00            edna    tx      us    circle
# 2      10/10/1960  20:00         kaneohe    hi      us     light
# 3      10/10/1961  19:00         bristol    tn      us    sphere
# 4      10/10/1965  23:45         norwalk    ct      us      disk
# ...           ...    ...             ...   ...     ...       ...
# 70288    9/9/2013  22:00            napa    ca      us     other
# 70289    9/9/2013  22:20          vienna    va      us    circle
# 70290    9/9/2013  23:00          edmond    ok      us     cigar
# 70291    9/9/2013  23:00           starr    sc      us   diamond
# 70292    9/9/2013  23:30  ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 1                     20             1/2 hour
# 2                    900           15 minutes
# 3                    300            5 minutes
# 4                   1200           20 minutes
# ...                  ...                  ...
# 70288             1200.0                 hour
# 70289                5.0            5 seconds
# 70290             1020.0           17 minutes
# 70291                0.0             2 nights
# 70292                0.0       still occuring
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 1      My older brother and twin sister were leaving ...   1/17/2004
# 2      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 3      My father is now 89 my brother 52 the girl wit...   4/27/2007
# 4      A bright orange color changing to reddish colo...   10/2/1999
# ...                                                  ...         ...
# 70288                                       Napa UFO&#44   9/30/2013
# 70289  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 70290  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
# 70291  On September ninth my wife and i noticed stran...   9/30/2013
# 70292  Hovering object lit with red and white lights&...   9/30/2013
#
#          latitude   longitude
# 0      29.8830556  -97.941111
# 1      28.9783333  -96.645833
# 2      21.4180556 -157.803611
# 3      36.5950000  -82.188889
# 4      41.1175000  -73.408333
# ...           ...         ...
# 70288   38.297222 -122.284444
# 70289   38.901111  -77.265556
# 70290   35.652778  -97.477778
# 70291   34.376944  -82.695833
# 70292   26.121944  -80.143611
#
# [70293 rows x 12 columns]

# %%
df_ufo_us.dtypes
# Out:
# date                     object
# time                     object
# city                     object
# state                    object
# country                  object
# shape                    object
# duration (seconds)       object
# duration (hours/min)     object
# comments                 object
# date posted              object
# latitude                 object
# longitude               float64
# dtype: object

# %%
df_ufo_us['date'] = pd.to_datetime(df_ufo_us['date'])
# Out:
# /tmp/ipykernel_21157/4259222884.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ufo_us['date'] = pd.to_datetime(df_ufo_us['date'])

# %%
df_ufo_us
# Out:
#             date   time            city state country     shape  \
# 0     1949-10-10  20:30      san marcos    tx      us  cylinder
# 3     1956-10-10  21:00            edna    tx      us    circle
# 4     1960-10-10  20:00         kaneohe    hi      us     light
# 5     1961-10-10  19:00         bristol    tn      us    sphere
# 7     1965-10-10  23:45         norwalk    ct      us      disk
# ...          ...    ...             ...   ...     ...       ...
# 88674 2013-09-09  22:00            napa    ca      us     other
# 88675 2013-09-09  22:20          vienna    va      us    circle
# 88676 2013-09-09  23:00          edmond    ok      us     cigar
# 88677 2013-09-09  23:00           starr    sc      us   diamond
# 88678 2013-09-09  23:30  ft. lauderdale    fl      us      oval
#
#       duration (seconds) duration (hours/min)  \
# 0                   2700           45 minutes
# 3                     20             1/2 hour
# 4                    900           15 minutes
# 5                    300            5 minutes
# 7                   1200           20 minutes
# ...                  ...                  ...
# 88674             1200.0                 hour
# 88675                5.0            5 seconds
# 88676             1020.0           17 minutes
# 88677                0.0             2 nights
# 88678                0.0       still occuring
#
#                                                 comments date posted  \
# 0      This event took place in early fall around 194...   4/27/2004
# 3      My older brother and twin sister were leaving ...   1/17/2004
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004
# 5      My father is now 89 my brother 52 the girl wit...   4/27/2007
# 7      A bright orange color changing to reddish colo...   10/2/1999
# ...                                                  ...         ...
# 88674                                       Napa UFO&#44   9/30/2013
# 88675  Saw a five gold lit cicular craft moving fastl...   9/30/2013
# 88676  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013
# 88677  On September ninth my wife and i noticed stran...   9/30/2013
# 88678  Hovering object lit with red and white lights&...   9/30/2013
#
#          latitude   longitude
# 0      29.8830556  -97.941111
# 3      28.9783333  -96.645833
# 4      21.4180556 -157.803611
# 5      36.5950000  -82.188889
# 7      41.1175000  -73.408333
# ...           ...         ...
# 88674   38.297222 -122.284444
# 88675   38.901111  -77.265556
# 88676   35.652778  -97.477778
# 88677   34.376944  -82.695833
# 88678   26.121944  -80.143611
#
# [70293 rows x 12 columns]

# %%
df_ufo_us = df_ufo_us.sort_values(by = 'date', ascending = True)
df_ufo_us = df_ufo_us.reset_index(drop = True)
df_ufo_us
# Out:
#             date   time                         city state country      shape  \
# 0     1910-01-01  24:00            kirksville (near)    mo      us       disk
# 1     1910-05-28  21:00                        solon    me      us    unknown
# 2     1910-06-01  15:00                  wills point    tx      us      cigar
# 3     1920-06-11  21:00                       cicero    in      us    unknown
# 4     1925-12-28  18:00  atkinson (6 miles north of)    il      us       disk
# ...          ...    ...                          ...   ...     ...        ...
# 70288 2014-05-07  09:30                  port richey    fl      us    unknown
# 70289 2014-05-07  03:30                       calera    al      us     circle
# 70290 2014-05-07  00:00                      detroit    mi      us   fireball
# 70291 2014-05-07  20:30               seagrove beach    fl      us   fireball
# 70292 2014-05-08  00:00                      memphis    tn      us  rectangle
#
#       duration (seconds) duration (hours/min)  \
# 0                    120              minutes
# 1                      0        don&#39t know
# 2                    120            2 minutes
# 3                     60             1 minute
# 4                     60             1 minute
# ...                  ...                  ...
# 70288                  1             1 second
# 70289                240          3-4 minutes
# 70290                180            3 minutes
# 70291                 60            <1 minute
# 70292                900           15 minutes
#
#                                                 comments date posted  \
# 0      Historical sighting (1903 - 1913) Northern Mis...   9/15/2005
# 1      entry in my great-grandmother&#39s diary&#44da...   12/5/2001
# 2           Cigar shaped object moving from West to East   4/16/2005
# 3      ((NUFORC Note:  Probable hoax.  Note date.  PD...   5/12/2009
# 4      Young boy witnesses disc in sky above Illinois...   5/11/2005
# ...                                                  ...         ...
# 70288  Sonic boom denied by military source per McDil...    5/8/2014
# 70289  Orange/red sphere with blue or green outline o...    5/8/2014
# 70290                         Fire balls in detroit sky.    5/8/2014
# 70291  Around 8:30 pm I was on the balcony of our con...    5/8/2014
# 70292  Standing at my window around 0:00 brilliantly ...    5/8/2014
#
#          latitude  longitude
# 0      40.1947222 -92.583056
# 1      44.9494444 -69.858889
# 2      32.7091667 -96.008056
# 3      40.1238889 -86.013333
# 4      41.4208333 -90.015000
# ...           ...        ...
# 70288  28.2713889 -82.719722
# 70289  33.1027778 -86.753611
# 70290  42.3313889 -83.045833
# 70291  30.3183333 -86.130278
# 70292  35.1494444 -90.048889
#
# [70293 rows x 12 columns]

# %%
df_ufo_us_mod = df_ufo_us.loc[df_ufo_us['date'] > '1994-12-31']

# %%
df_ufo_us_mod.reset_index(drop = True)
# Out:
#             date   time            city state country      shape  \
# 0     1995-01-01  02:00      el granada    ca      us   fireball
# 1     1995-01-01  15:00       cedar key    fl      us   triangle
# 2     1995-01-01  15:00       greenwood    sc      us     sphere
# 3     1995-01-01  21:00          tucson    az      us   triangle
# 4     1995-01-01  00:02   pacific grove    ca      us        NaN
# ...          ...    ...             ...   ...     ...        ...
# 63782 2014-05-07  09:30     port richey    fl      us    unknown
# 63783 2014-05-07  03:30          calera    al      us     circle
# 63784 2014-05-07  00:00         detroit    mi      us   fireball
# 63785 2014-05-07  20:30  seagrove beach    fl      us   fireball
# 63786 2014-05-08  00:00         memphis    tn      us  rectangle
#
#       duration (seconds) duration (hours/min)  \
# 0                     45           45 seconds
# 1                    180            3 minutes
# 2                     20           20 seconds
# 3                    600         5-10 minutes
# 4                      0                  NaN
# ...                  ...                  ...
# 63782                  1             1 second
# 63783                240          3-4 minutes
# 63784                180            3 minutes
# 63785                 60            <1 minute
# 63786                900           15 minutes
#
#                                                 comments date posted  \
# 0      Glowing fireball  object crashed at Maverick&#...   11/4/2002
# 1           I could hear and see it&#44 close encounter.   8/16/2002
# 2      Bright red sphere floating and completely sile...   7/14/2013
# 3      120-140 ft&#44 X 35-40 ft&#44 X 30 ft&#44 tria...    3/7/1998
# 4      Rept. that local police had pursued a strange ...   11/2/1999
# ...                                                  ...         ...
# 63782  Sonic boom denied by military source per McDil...    5/8/2014
# 63783  Orange/red sphere with blue or green outline o...    5/8/2014
# 63784                         Fire balls in detroit sky.    5/8/2014
# 63785  Around 8:30 pm I was on the balcony of our con...    5/8/2014
# 63786  Standing at my window around 0:00 brilliantly ...    5/8/2014
#
#          latitude   longitude
# 0      37.5027778 -122.468333
# 1      29.1383333  -83.035278
# 2      34.1952778  -82.161944
# 3      32.2216667 -110.925833
# 4      36.6177778 -121.915556
# ...           ...         ...
# 63782  28.2713889  -82.719722
# 63783  33.1027778  -86.753611
# 63784  42.3313889  -83.045833
# 63785  30.3183333  -86.130278
# 63786  35.1494444  -90.048889
#
# [63787 rows x 12 columns]

# %%
df_ufo_us_mod['shape'] = df_ufo_us_mod['shape'].fillna('unknown')
# Out:
# /tmp/ipykernel_21157/1921904223.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ufo_us_mod['shape'] = df_ufo_us_mod['shape'].fillna('unknown')

# %%
df_ufo_us_mod = df_ufo_us_mod.drop(columns = ['duration (hours/min)','date posted', 'country'])

# %%
df_ufo_us_mod
# Out:
#             date   time            city state      shape duration (seconds)  \
# 6506  1995-01-01  02:00      el granada    ca   fireball                 45
# 6507  1995-01-01  15:00       cedar key    fl   triangle                180
# 6508  1995-01-01  15:00       greenwood    sc     sphere                 20
# 6509  1995-01-01  21:00          tucson    az   triangle                600
# 6510  1995-01-01  00:02   pacific grove    ca    unknown                  0
# ...          ...    ...             ...   ...        ...                ...
# 70288 2014-05-07  09:30     port richey    fl    unknown                  1
# 70289 2014-05-07  03:30          calera    al     circle                240
# 70290 2014-05-07  00:00         detroit    mi   fireball                180
# 70291 2014-05-07  20:30  seagrove beach    fl   fireball                 60
# 70292 2014-05-08  00:00         memphis    tn  rectangle                900
#
#                                                 comments    latitude  \
# 6506   Glowing fireball  object crashed at Maverick&#...  37.5027778
# 6507        I could hear and see it&#44 close encounter.  29.1383333
# 6508   Bright red sphere floating and completely sile...  34.1952778
# 6509   120-140 ft&#44 X 35-40 ft&#44 X 30 ft&#44 tria...  32.2216667
# 6510   Rept. that local police had pursued a strange ...  36.6177778
# ...                                                  ...         ...
# 70288  Sonic boom denied by military source per McDil...  28.2713889
# 70289  Orange/red sphere with blue or green outline o...  33.1027778
# 70290                         Fire balls in detroit sky.  42.3313889
# 70291  Around 8:30 pm I was on the balcony of our con...  30.3183333
# 70292  Standing at my window around 0:00 brilliantly ...  35.1494444
#
#         longitude
# 6506  -122.468333
# 6507   -83.035278
# 6508   -82.161944
# 6509  -110.925833
# 6510  -121.915556
# ...           ...
# 70288  -82.719722
# 70289  -86.753611
# 70290  -83.045833
# 70291  -86.130278
# 70292  -90.048889
#
# [63787 rows x 9 columns]

# %% [markdown]
# #### UFO data 데이터 베이스 저장

# %%
import mysql.connector
import os
from dotenv import load_dotenv
from mysql.connector import Error

# %%
load_dotenv()
aws_db_ufo_pw = os.getenv('aws_db_ufo_pw')
aws_host_ufo = os.getenv('aws_host_ufo')

# %%
remote = mysql.connector.connect(
    host = aws_host_ufo,
    user = 'EDA',
    port = 3306,  # default 는 3306
    password = aws_db_ufo_pw,
    database = 'Frisbee'

)

cursor = remote.cursor()

# %%
cursor.close()
# Out:
# True

# %%
df_ufo_us_mod
# Out:
#             date   time            city state      shape duration (seconds)  \
# 6506  1995-01-01  02:00      el granada    ca   fireball                 45
# 6507  1995-01-01  15:00       cedar key    fl   triangle                180
# 6508  1995-01-01  15:00       greenwood    sc     sphere                 20
# 6509  1995-01-01  21:00          tucson    az   triangle                600
# 6510  1995-01-01  00:02   pacific grove    ca    unknown                  0
# ...          ...    ...             ...   ...        ...                ...
# 70288 2014-05-07  09:30     port richey    fl    unknown                  1
# 70289 2014-05-07  03:30          calera    al     circle                240
# 70290 2014-05-07  00:00         detroit    mi   fireball                180
# 70291 2014-05-07  20:30  seagrove beach    fl   fireball                 60
# 70292 2014-05-08  00:00         memphis    tn  rectangle                900
#
#                                                 comments    latitude  \
# 6506   Glowing fireball  object crashed at Maverick&#...  37.5027778
# 6507        I could hear and see it&#44 close encounter.  29.1383333
# 6508   Bright red sphere floating and completely sile...  34.1952778
# 6509   120-140 ft&#44 X 35-40 ft&#44 X 30 ft&#44 tria...  32.2216667
# 6510   Rept. that local police had pursued a strange ...  36.6177778
# ...                                                  ...         ...
# 70288  Sonic boom denied by military source per McDil...  28.2713889
# 70289  Orange/red sphere with blue or green outline o...  33.1027778
# 70290                         Fire balls in detroit sky.  42.3313889
# 70291  Around 8:30 pm I was on the balcony of our con...  30.3183333
# 70292  Standing at my window around 0:00 brilliantly ...  35.1494444
#
#         longitude
# 6506  -122.468333
# 6507   -83.035278
# 6508   -82.161944
# 6509  -110.925833
# 6510  -121.915556
# ...           ...
# 70288  -82.719722
# 70289  -86.753611
# 70290  -83.045833
# 70291  -86.130278
# 70292  -90.048889
#
# [63787 rows x 9 columns]

# %%
df_ufo_us_mod.dropna(inplace = True)

# %%
df_ufo_us_mod
# Out:
#             date   time            city state      shape duration (seconds)  \
# 6506  1995-01-01  02:00      el granada    ca   fireball                 45
# 6507  1995-01-01  15:00       cedar key    fl   triangle                180
# 6508  1995-01-01  15:00       greenwood    sc     sphere                 20
# 6509  1995-01-01  21:00          tucson    az   triangle                600
# 6510  1995-01-01  00:02   pacific grove    ca    unknown                  0
# ...          ...    ...             ...   ...        ...                ...
# 70288 2014-05-07  09:30     port richey    fl    unknown                  1
# 70289 2014-05-07  03:30          calera    al     circle                240
# 70290 2014-05-07  00:00         detroit    mi   fireball                180
# 70291 2014-05-07  20:30  seagrove beach    fl   fireball                 60
# 70292 2014-05-08  00:00         memphis    tn  rectangle                900
#
#                                                 comments    latitude  \
# 6506   Glowing fireball  object crashed at Maverick&#...  37.5027778
# 6507        I could hear and see it&#44 close encounter.  29.1383333
# 6508   Bright red sphere floating and completely sile...  34.1952778
# 6509   120-140 ft&#44 X 35-40 ft&#44 X 30 ft&#44 tria...  32.2216667
# 6510   Rept. that local police had pursued a strange ...  36.6177778
# ...                                                  ...         ...
# 70288  Sonic boom denied by military source per McDil...  28.2713889
# 70289  Orange/red sphere with blue or green outline o...  33.1027778
# 70290                         Fire balls in detroit sky.  42.3313889
# 70291  Around 8:30 pm I was on the balcony of our con...  30.3183333
# 70292  Standing at my window around 0:00 brilliantly ...  35.1494444
#
#         longitude
# 6506  -122.468333
# 6507   -83.035278
# 6508   -82.161944
# 6509  -110.925833
# 6510  -121.915556
# ...           ...
# 70288  -82.719722
# 70289  -86.753611
# 70290  -83.045833
# 70291  -86.130278
# 70292  -90.048889
#
# [63761 rows x 9 columns]

# %%
table_name = 'UFO_us'

query_create_table = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            date DATETIME,
            time DATETIME,
            city CHAR(16),
            state CHAR(4),
            shape CHAR(16),
            duration INT,
            comments TEXT,
            latitude FLOAT,
            longitude FLOAT
        )
        """
        
cursor.execute(query_create_table)
remote.commit()
print(f"테이블 '{table_name}'이(가) 성공적으로 생성되었거나 이미 존재합니다.")
# Out:
# 테이블 'UFO_us'이(가) 성공적으로 생성되었거나 이미 존재합니다.

# %%
for idx, row in df_ufo_us_mod.iterrows():

    query = f"""
    INSERT INTO {table_name} (date, time, city, state, shape, duration, comments, latitude, longitude)
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
    """

    cursor.execute(query, tuple(row))
    
    
remote.commit()
print(f"{cursor.rowcount} 개의 ROW가 {table_name} 테이블에 성공적으로 삽입 되었습니다")
# Out:
# 1 개의 ROW가 UFO_us 테이블에 성공적으로 삽입 되었습니다

# %%
df_ufo_us_mod.to_csv('/home/roni/dev_ws/ufo_eda/data/ufo_us.csv')

# %%
df_mag
# Out:
#            date         bt  theta_gse     phi_gse  theta_gsm     phi_gsm
# 0    2018-11-08   4.201618   1.639833  124.072722  -7.467917  126.339301
# 1    2018-11-09   5.654160 -18.319604  203.009965 -18.635729  221.180469
# 2    2018-11-10   8.013868   1.358437  286.612578  10.584306  283.317374
# 3    2018-11-11   4.885163   5.908899  279.866334  13.607603  272.854985
# 4    2018-11-12   4.114291  -4.749343  231.083344  -0.697394  225.140376
# ...         ...        ...        ...         ...        ...         ...
# 1626 2023-11-05  19.863812  -1.501554  220.622625   6.811093  232.189722
# 1627 2023-11-06  11.346820  -9.671675  241.561084  -1.399630  237.211461
# 1628 2023-11-07   6.045146   9.152118  206.763660  10.159028  193.063896
# 1629 2023-11-08   5.563336  12.647262  258.011492  19.430773  232.937846
# 1630 2023-11-09   4.035942  -0.494623  269.740072  10.117246  265.152613
#
# [1631 rows x 6 columns]

# %%
df_ufo_us = df_ufo_us_mod.reset_index(drop=True)
df_ufo_us.to_csv('/home/roni/dev_ws/ufo_eda/data/ufo_us.csv')

# %%
us_state_to_name_lower = {
    'ak': 'alaska', 'al': 'alabama', 'ar': 'arkansas', 'az': 'arizona',
    'ca': 'california', 'co': 'colorado', 'ct': 'connecticut', 'dc': 'district of columbia',
    'de': 'delaware', 'fl': 'florida', 'ga': 'georgia', 'hi': 'hawaii',
    'ia': 'iowa', 'id': 'idaho', 'il': 'illinois', 'in': 'indiana',
    'ks': 'kansas', 'ky': 'kentucky', 'la': 'louisiana', 'ma': 'massachusetts',
    'md': 'maryland', 'me': 'maine', 'mi': 'michigan', 'mn': 'minnesota',
    'mo': 'missouri', 'ms': 'mississippi', 'mt': 'montana', 'nc': 'north carolina',
    'nd': 'north dakota', 'ne': 'nebraska', 'nh': 'new hampshire', 'nj': 'new jersey',
    'nm': 'new mexico', 'nv': 'nevada', 'ny': 'new york', 'oh': 'ohio',
    'ok': 'oklahoma', 'or': 'oregon', 'pa': 'pennsylvania', 'ri': 'rhode island',
    'sc': 'south carolina', 'sd': 'south dakota', 'tn': 'tennessee', 'tx': 'texas',
    'ut': 'utah', 'va': 'virginia', 'vt': 'vermont', 'wa': 'washington',
    'wi': 'wisconsin', 'wv': 'west virginia', 'wy': 'wyoming'
}

# %%
df_ufo_us['state_name'] = df_ufo_us['state'].map(us_state_to_name_lower)

# %%
df_ufo_us
# Out:
#             date   time            city state      shape duration (seconds)  \
# 0     1995-01-01  02:00      el granada    ca   fireball                 45
# 1     1995-01-01  15:00       cedar key    fl   triangle                180
# 2     1995-01-01  15:00       greenwood    sc     sphere                 20
# 3     1995-01-01  21:00          tucson    az   triangle                600
# 4     1995-01-01  00:02   pacific grove    ca    unknown                  0
# ...          ...    ...             ...   ...        ...                ...
# 63756 2014-05-07  09:30     port richey    fl    unknown                  1
# 63757 2014-05-07  03:30          calera    al     circle                240
# 63758 2014-05-07  00:00         detroit    mi   fireball                180
# 63759 2014-05-07  20:30  seagrove beach    fl   fireball                 60
# 63760 2014-05-08  00:00         memphis    tn  rectangle                900
#
#                                                 comments    latitude  \
# 0      Glowing fireball  object crashed at Maverick&#...  37.5027778
# 1           I could hear and see it&#44 close encounter.  29.1383333
# 2      Bright red sphere floating and completely sile...  34.1952778
# 3      120-140 ft&#44 X 35-40 ft&#44 X 30 ft&#44 tria...  32.2216667
# 4      Rept. that local police had pursued a strange ...  36.6177778
# ...                                                  ...         ...
# 63756  Sonic boom denied by military source per McDil...  28.2713889
# 63757  Orange/red sphere with blue or green outline o...  33.1027778
# 63758                         Fire balls in detroit sky.  42.3313889
# 63759  Around 8:30 pm I was on the balcony of our con...  30.3183333
# 63760  Standing at my window around 0:00 brilliantly ...  35.1494444
#
#         longitude      state_name
# 0     -122.468333      california
# 1      -83.035278         florida
# 2      -82.161944  south carolina
# 3     -110.925833         arizona
# 4     -121.915556      california
# ...           ...             ...
# 63756  -82.719722         florida
# 63757  -86.753611         alabama
# 63758  -83.045833        michigan
# 63759  -86.130278         florida
# 63760  -90.048889       tennessee
#
# [63761 rows x 10 columns]

# %%
df_ufo_us_state = df_ufo_us.groupby(by = 'state_name').size()

# %%
df_ufo_us_state
# Out:
# state_name
# alabama                  616
# alaska                   302
# arizona                 2504
# arkansas                 569
# california              8748
# colorado                1418
# connecticut              846
# delaware                 158
# district of columbia       7
# florida                 3863
# georgia                 1234
# hawaii                   249
# idaho                    525
# illinois                2484
# indiana                 1261
# iowa                     661
# kansas                   586
# kentucky                 811
# louisiana                517
# maine                    521
# maryland                 797
# massachusetts           1183
# michigan                1759
# minnesota                994
# mississippi              342
# missouri                1410
# montana                  484
# nebraska                 365
# nevada                   800
# new hampshire            463
# new jersey              1196
# new mexico               713
# new york                2802
# north carolina          1703
# north dakota             120
# ohio                    2186
# oklahoma                 694
# oregon                  1757
# pennsylvania            2261
# rhode island             222
# south carolina          1012
# south dakota             172
# tennessee               1127
# texas                   3337
# utah                     606
# vermont                  267
# virginia                1254
# washington              4031
# west virginia            441
# wisconsin               1197
# wyoming                  169
# dtype: int64

# %% [markdown]
# ### Space weather

# %% [markdown]
# #### 전처리

# %%
import pandas as pd

# %%
df_sw = pd.read_csv('/home/roni/dev_ws/ufo_eda/data/space_weather.csv')

# %% [markdown]
# ##### 데이터 정보
# 컬럼 설명
#
# - DATE: 관측 날짜 (예: 1957-10-01)
#
# - BSRN: 바텔스 태양 회전 번호 (태양의 자전 주기를 기준으로 한 번호)
#
# - ND: 바텔스 회전 주기 내에서의 일(day) 번호
#
# - KP1 ~ KP8: 하루를 3시간 간격으로 나눈 8개의 구간에 대한 Kp 지수 (지구 자기장 활동을 나타내는 지수)
#
# - KP_SUM: 8개 구간의 Kp 지수 일일 합계
#
# - AP1 ~ AP8: 하루를 3시간 간격으로 나눈 8개의 구간에 대한 Ap 지수 (Kp와 유사한 지구 자기장 활동 지수)
#
# - AP_AVG: 8개 구간의 Ap 지수 일일 평균
#
# - CP: Cp 지수 (지구 자기장 활동 관련 지수)
#
# - C9: C9 지수 (지구 자기장 활동 관련 지수)
#
# - ISN: 국제 흑점 수 (태양 활동의 지표)
#
# - F10.7_OBS: 관측된 10.7cm 파장의 태양 전파 플럭스 (태양 활동의 주요 지표)
#
# - F10.7_ADJ: 1 천문단위(AU) 거리 기준으로 보정된 F10.7 플럭스 값
#
# - F10.7_DATA_TYPE: F10.7 데이터 유형 (예: 'OBS' - 관측값)
#
# - F10.7_OBS_CENTER81: 81일 중심 이동 평균을 적용한 관측 F10.7 플럭스
#
# - F10.7_OBS_LAST81: 81일 후행 이동 평균을 적용한 관측 F10.7 플럭스
#
# - F10.7_ADJ_CENTER81: 81일 중심 이동 평균을 적용한 보정 F10.7 플럭스
#
# - F10.7_ADJ_LAST81: 81일 후행 이동 평균을 적용한 보정 F10.7 플럭스

# %%
df_sw
# Out:
#              DATE  BSRN  ND   KP1   KP2   KP3   KP4   KP5   KP6   KP7  ...  \
# 0      1957-10-01  1700  19  43.0  40.0  30.0  20.0  37.0  23.0  43.0  ...
# 1      1957-10-02  1700  20  37.0  37.0  17.0  17.0  27.0  23.0  17.0  ...
# 2      1957-10-03  1700  21  27.0  20.0  13.0  33.0  37.0  47.0  43.0  ...
# 3      1957-10-04  1700  22  30.0  30.0  23.0  27.0  23.0  27.0  30.0  ...
# 4      1957-10-05  1700  23  30.0  30.0  17.0  23.0  20.0  27.0  27.0  ...
# ...           ...   ...  ..   ...   ...   ...   ...   ...   ...   ...  ...
# 25087  2041-06-01  2832  14   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 25088  2041-07-01  2833  17   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 25089  2041-08-01  2834  21   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 25090  2041-09-01  2835  25   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 25091  2041-10-01  2837   1   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#         CP   C9  ISN  F10.7_OBS  F10.7_ADJ  F10.7_DATA_TYPE  \
# 0      1.1  5.0  334      269.3      269.8              OBS
# 1      0.7  3.0  331      253.3      253.6              OBS
# 2      1.0  5.0  343      266.3      266.4              OBS
# 3      0.7  3.0  307      238.2      238.2              OBS
# 4      0.6  3.0  310      246.2      246.0              OBS
# ...    ...  ...  ...        ...        ...              ...
# 25087  NaN  NaN   13       69.2       71.1              PRM
# 25088  NaN  NaN   12       68.5       70.8              PRM
# 25089  NaN  NaN   11       68.4       70.5              PRM
# 25090  NaN  NaN   11       68.9       70.2              PRM
# 25091  NaN  NaN   10       69.8       70.0              PRM
#
#        F10.7_OBS_CENTER81  F10.7_OBS_LAST81  F10.7_ADJ_CENTER81  \
# 0                   266.6             230.9               266.8
# 1                   267.4             231.7               267.5
# 2                   268.1             232.7               268.1
# 3                   268.8             233.3               268.7
# 4                   269.3             233.9               269.1
# ...                   ...               ...                 ...
# 25087                69.5              71.1                71.3
# 25088                68.8              69.8                71.0
# 25089                68.7              69.0                70.6
# 25090                69.2              68.7                70.4
# 25091                68.8              69.0                69.2
#
#        F10.7_ADJ_LAST81
# 0                 235.5
# 1                 236.2
# 2                 237.1
# 3                 237.7
# 4                 238.1
# ...                 ...
# 25087              71.7
# 25088              71.4
# 25089              71.1
# 25090              70.7
# 25091              70.5
#
# [25092 rows x 31 columns]

# %%
df_sw.dtypes
# Out:
# DATE                   object
# BSRN                    int64
# ND                      int64
# KP1                   float64
# KP2                   float64
# KP3                   float64
# KP4                   float64
# KP5                   float64
# KP6                   float64
# KP7                   float64
# KP8                   float64
# KP_SUM                float64
# AP1                   float64
# AP2                   float64
# AP3                   float64
# AP4                   float64
# AP5                   float64
# AP6                   float64
# AP7                   float64
# AP8                   float64
# AP_AVG                float64
# CP                    float64
# C9                    float64
# ISN                     int64
# F10.7_OBS             float64
# F10.7_ADJ             float64
# F10.7_DATA_TYPE        object
# F10.7_OBS_CENTER81    float64
# F10.7_OBS_LAST81      float64
# F10.7_ADJ_CENTER81    float64
# F10.7_ADJ_LAST81      float64
# dtype: object

# %%
df_sw.columns
# Out:
# Index(['DATE', 'BSRN', 'ND', 'KP1', 'KP2', 'KP3', 'KP4', 'KP5', 'KP6', 'KP7',
#        'KP8', 'KP_SUM', 'AP1', 'AP2', 'AP3', 'AP4', 'AP5', 'AP6', 'AP7', 'AP8',
#        'AP_AVG', 'CP', 'C9', 'ISN', 'F10.7_OBS', 'F10.7_ADJ',
#        'F10.7_DATA_TYPE', 'F10.7_OBS_CENTER81', 'F10.7_OBS_LAST81',
#        'F10.7_ADJ_CENTER81', 'F10.7_ADJ_LAST81'],
#       dtype='object')

# %%
df_sw_core = df_sw[['DATE', 'AP_AVG', 'ISN', 'F10.7_ADJ']]

# %%
df_sw_core['DATE'] = pd.to_datetime(df_sw_core['DATE'])
# Out:
# /tmp/ipykernel_15129/3277148040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sw_core['DATE'] = pd.to_datetime(df_sw_core['DATE'])

# %%
df_sw_core = df_sw_core.loc[df_sw_core['DATE'] > '1993-12-31']
df_sw_core = df_sw_core.loc[df_sw_core['DATE'] < '2025-1-1']

# %%
df_sw_core = df_sw_core.sort_values(by = 'DATE', ascending= True)
df_sw_core = df_sw_core.reset_index(drop = True)

# %%
df_sw_core
# Out:
#             DATE  AP_AVG  ISN  F10.7_ADJ
# 0     1994-01-01    26.0  126      143.4
# 1     1994-01-02    21.0  113      141.4
# 2     1994-01-03    15.0  136      128.7
# 3     1994-01-04     6.0  151      124.6
# 4     1994-01-05     4.0  153      132.4
# ...          ...     ...  ...        ...
# 11318 2024-12-27     2.0  257      250.0
# 11319 2024-12-28     3.0  254      251.8
# 11320 2024-12-29     4.0  233      246.3
# 11321 2024-12-30     6.0  218      216.1
# 11322 2024-12-31    13.0  183      210.4
#
# [11323 rows x 4 columns]

# %% [markdown]
# #### Space weather 데이터 베이스 저장

# %%
import mysql.connector
import os
from dotenv import load_dotenv
from mysql.connector import Error

# %%
load_dotenv()
aws_db_ufo_pw = os.getenv('aws_db_ufo_pw')
aws_host_ufo = os.getenv('aws_host_ufo')

# %%
remote = mysql.connector.connect(
    host = aws_host_ufo,
    user = 'EDA',
    port = 3306,  # default 는 3306
    password = aws_db_ufo_pw,
    database = 'Frisbee'

)

cursor = remote.cursor()

# %%
cursor.close()
# Out:
# True

# %%
df_sw_core
# Out:
#             DATE  AP_AVG  ISN  F10.7_ADJ
# 0     1994-01-01    26.0  126      143.4
# 1     1994-01-02    21.0  113      141.4
# 2     1994-01-03    15.0  136      128.7
# 3     1994-01-04     6.0  151      124.6
# 4     1994-01-05     4.0  153      132.4
# ...          ...     ...  ...        ...
# 11318 2024-12-27     2.0  257      250.0
# 11319 2024-12-28     3.0  254      251.8
# 11320 2024-12-29     4.0  233      246.3
# 11321 2024-12-30     6.0  218      216.1
# 11322 2024-12-31    13.0  183      210.4
#
# [11323 rows x 4 columns]

# %%
table_name = 'space_weather'

query_create_table = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            date DATETIME,
            ap_avg FLOAT,
            black_dot_cnt INT,
            f107_adj FLOAT
            )
        """
        
cursor.execute(query_create_table)
remote.commit()
print(f"테이블 '{table_name}'이(가) 성공적으로 생성되었거나 이미 존재합니다.")
# Out:
# 테이블 'space_weather'이(가) 성공적으로 생성되었거나 이미 존재합니다.

# %%
for idx, row in df_sw_core.iterrows():

    query = f"""
    INSERT INTO {table_name} (date, ap_avg, black_dot_cnt, f107_adj)
    VALUES (%s,%s,%s,%s)
    """

    cursor.execute(query, tuple(row))
    
    
remote.commit()
print(f"{cursor.rowcount} 개의 ROW가 {table_name} 테이블에 성공적으로 삽입 되었습니다")
# Out:
# 1 개의 ROW가 space_weather 테이블에 성공적으로 삽입 되었습니다

# %%
df_sw_core.to_csv('/home/roni/dev_ws/ufo_eda/data/sw_core.csv')

# %% [markdown]
# ### 유성우 데이터

# %% [markdown]
# #### preprocess

# %%
df_metheo = pd.read_csv('/home/roni/dev_ws/ufo_eda/data/metheo.csv')

# %%
df_metheo.head()
# Out:
#    Unnamed: 0              Address Latitude Longitude Elevation  \
# 0           0  Leilani Estates, HI      19°     -154°      231m
# 1           1         Claypool, IN      41°      -85°      272m
# 2           2           Seguin, TX      29°      -97°      141m
# 3           3      Gulf Shores, AL      30°      -87°        5m
# 4           4         O'Fallon, IL      38°      -89°      173m
#
#       Local Date & Time       UT Date & Time Duration  \
# 0  1997-03-27 02:00 HST  1997-03-27 12:00 UT        -
# 1  2011-07-01 21:30 EDT  2011-07-02 01:30 UT        -
# 2  2004-12-17 23:00 CDT  2004-12-18 05:00 UT        -
# 3  2004-10-12 02:14 CDT  2004-10-12 07:14 UT        -
# 4  2007-02-04 18:30 CST  2007-02-05 00:30 UT       5s
#
#              Moving direction Descent Angle  ... First elevation Last azimuth  \
# 0  From up left to down right           98°  ...             31°      150.79°
# 1  From up left to down right           97°  ...             35°       98.42°
# 2  From up right to down left          181°  ...             90°       81.76°
# 3          From left to right           90°  ...             32°      123.54°
# 4  From up left to down right          133°  ...             49°          90°
#
#   Last elevation Stellar Magnitude                Color Observation  \
# 0            13°               -16                White          No
# 1            29°               -20                White     Unknown
# 2             1°               -24   Green, Light Green          No
# 3            20°               -13  Orange, Yellow, Red         Yes
# 4             1°               -13   Orange then Yellow          No
#
#                                              Remarks Length       Name  \
# 0  I was sound asleep and saw 2 white eggs, it wa...      -  Deborah P
# 1  At the time I was running with a friend Katy B...      -   Curtis B
# 2  It can from almost directly above me and lande...      -     Greg O
# 3  This was slow low alt. Massive meteor... actua...      -   Thomas M
# 4                                                  -    80°     Lawa M
#
#   Experience Level
# 0              2/5
# 1              3/5
# 2              3/5
# 3              5/5
# 4              3/5
#
# [5 rows x 22 columns]

# %%
df_metheo_cols = list(df_metheo.columns)
print(df_metheo_cols)
# Out:
# ['Unnamed: 0', 'Address', 'Latitude', 'Longitude', 'Elevation', 'Local Date & Time', 'UT Date & Time', 'Duration', 'Moving direction', 'Descent Angle', 'Facing azimuth', 'First azimuth', 'First elevation', 'Last azimuth', 'Last elevation', 'Stellar Magnitude', 'Color', 'Observation', 'Remarks', 'Length', 'Name', 'Experience Level']

# %%
df_metheo_core = df_metheo[['Address', 'Latitude', 'Longitude', 'Elevation', 'Local Date & Time','Stellar Magnitude','Color']]

# %%
df_metheo_core
# Out:
#                    Address Latitude Longitude Elevation     Local Date & Time  \
# 0      Leilani Estates, HI      19°     -154°      231m  1997-03-27 02:00 HST
# 1             Claypool, IN      41°      -85°      272m  2011-07-01 21:30 EDT
# 2               Seguin, TX      29°      -97°      141m  2004-12-17 23:00 CDT
# 3          Gulf Shores, AL      30°      -87°        5m  2004-10-12 02:14 CDT
# 4             O'Fallon, IL      38°      -89°      173m  2007-02-04 18:30 CST
# ...                    ...      ...       ...       ...                   ...
# 11003            Elgin, IL      42°      -88°      246m  2014-08-23 21:00 CDT
# 11004            niles, IL      42°      -87°         -  2014-08-23 21:15 CDT
# 11005      Bolingbrook, IL      41°      -88°         -  2014-08-23 21:10 CDT
# 11006         Evanston, IL      42°      -87°      184m  2014-08-23 21:15 CDT
# 11007      Farmer City, IL      40°      -88°         -  2014-08-23 21:10 CDT
#
#       Stellar Magnitude                  Color
# 0                   -16                  White
# 1                   -20                  White
# 2                   -24     Green, Light Green
# 3                   -13    Orange, Yellow, Red
# 4                   -13     Orange then Yellow
# ...                 ...                    ...
# 11003               -24           Green, White
# 11004               -13                  green
# 11005               -24             BLUE GREEN
# 11006               -10            Orange, Red
# 11007                -9  Blue, some saw green
#
# [11008 rows x 7 columns]

# %%
df_metheo_core['Elevation'].value_counts()
# Out:
# Elevation
# -        3514
# 3m         83
# 2m         69
# 5m         65
# 1m         57
#          ...
# 2195m       1
# 1950m       1
# 1672m       1
# 654m        1
# 2175m       1
# Name: count, Length: 968, dtype: int64

# %%
state_list = []
for addr in df_metheo_core['Address']:
     state_list.append(addr.split(',')[-1])
     
df_metheo_core['state'] = state_list
     
     
df_metheo_core['Latitude'] = df_metheo_core['Latitude'].str.replace('°','')
df_metheo_core['Longitude'] = df_metheo_core['Longitude'].str.replace('°','')
     
df_metheo_core['Elevation'] = df_metheo_core['Elevation'].str.replace('m','')
# Out:
# /tmp/ipykernel_15129/51017831.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['state'] = state_list
# /tmp/ipykernel_15129/51017831.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['Latitude'] = df_metheo_core['Latitude'].str.replace('°','')
# /tmp/ipykernel_15129/51017831.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['Longitude'] = df_metheo_core['Longitude'].str.replace('°','')
# /tmp/ipykernel_15129/51017831.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['Elevation'] = df_metheo_core['Elevation'].str.replace('m','')

# %%
df_metheo_core
# Out:
#                    Address Latitude Longitude Elevation     Local Date & Time  \
# 0      Leilani Estates, HI       19      -154       231  1997-03-27 02:00 HST
# 1             Claypool, IN       41       -85       272  2011-07-01 21:30 EDT
# 2               Seguin, TX       29       -97       141  2004-12-17 23:00 CDT
# 3          Gulf Shores, AL       30       -87         5  2004-10-12 02:14 CDT
# 4             O'Fallon, IL       38       -89       173  2007-02-04 18:30 CST
# ...                    ...      ...       ...       ...                   ...
# 11003            Elgin, IL       42       -88       246  2014-08-23 21:00 CDT
# 11004            niles, IL       42       -87         -  2014-08-23 21:15 CDT
# 11005      Bolingbrook, IL       41       -88         -  2014-08-23 21:10 CDT
# 11006         Evanston, IL       42       -87       184  2014-08-23 21:15 CDT
# 11007      Farmer City, IL       40       -88         -  2014-08-23 21:10 CDT
#
#       Stellar Magnitude                  Color state
# 0                   -16                  White    HI
# 1                   -20                  White    IN
# 2                   -24     Green, Light Green    TX
# 3                   -13    Orange, Yellow, Red    AL
# 4                   -13     Orange then Yellow    IL
# ...                 ...                    ...   ...
# 11003               -24           Green, White    IL
# 11004               -13                  green    IL
# 11005               -24             BLUE GREEN    IL
# 11006               -10            Orange, Red    IL
# 11007                -9  Blue, some saw green     IL
#
# [11008 rows x 8 columns]

# %%
color_list = ['white', 'red', 'blue', 'green', 'purple','orange', 'yellow']
safe_color_series = df_metheo_core['Color'].astype(str).str.lower()

# %%
for color in color_list:
    
    mask = safe_color_series.str.contains(color)
    
    df_metheo_core[color] = mask
# Out:
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask
# /tmp/ipykernel_15129/1839210142.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core[color] = mask

# %%
df_metheo_core
# Out:
#                    Address Latitude Longitude Elevation     Local Date & Time  \
# 0      Leilani Estates, HI       19      -154       231  1997-03-27 02:00 HST
# 1             Claypool, IN       41       -85       272  2011-07-01 21:30 EDT
# 2               Seguin, TX       29       -97       141  2004-12-17 23:00 CDT
# 3          Gulf Shores, AL       30       -87         5  2004-10-12 02:14 CDT
# 4             O'Fallon, IL       38       -89       173  2007-02-04 18:30 CST
# ...                    ...      ...       ...       ...                   ...
# 11003            Elgin, IL       42       -88       246  2014-08-23 21:00 CDT
# 11004            niles, IL       42       -87         -  2014-08-23 21:15 CDT
# 11005      Bolingbrook, IL       41       -88         -  2014-08-23 21:10 CDT
# 11006         Evanston, IL       42       -87       184  2014-08-23 21:15 CDT
# 11007      Farmer City, IL       40       -88         -  2014-08-23 21:10 CDT
#
#       Stellar Magnitude                  Color state  white    red   blue  \
# 0                   -16                  White    HI   True  False  False
# 1                   -20                  White    IN   True  False  False
# 2                   -24     Green, Light Green    TX  False  False  False
# 3                   -13    Orange, Yellow, Red    AL  False   True  False
# 4                   -13     Orange then Yellow    IL  False  False  False
# ...                 ...                    ...   ...    ...    ...    ...
# 11003               -24           Green, White    IL   True  False  False
# 11004               -13                  green    IL  False  False  False
# 11005               -24             BLUE GREEN    IL  False  False   True
# 11006               -10            Orange, Red    IL  False   True  False
# 11007                -9  Blue, some saw green     IL  False  False   True
#
#        green  purple  orange  yellow
# 0      False   False   False   False
# 1      False   False   False   False
# 2       True   False   False   False
# 3      False   False    True    True
# 4      False   False    True    True
# ...      ...     ...     ...     ...
# 11003   True   False   False   False
# 11004   True   False   False   False
# 11005   True   False   False   False
# 11006  False   False    True   False
# 11007   True   False   False   False
#
# [11008 rows x 15 columns]

# %%
date_list = []
time_list = []

for dt in df_metheo_core['Local Date & Time']:
    date_time_splitted = dt.split(' ')
    date = date_time_splitted[0]
    time = date_time_splitted[1]
    
    date_list.append(date)
    time_list.append(time)
    
    
df_metheo_core['date'] = date_list
df_metheo_core['time'] = time_list
# Out:
# /tmp/ipykernel_15129/3801598562.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['date'] = date_list
# /tmp/ipykernel_15129/3801598562.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['time'] = time_list

# %%
df_metheo_core['date'] = pd.to_datetime(df_metheo_core['date'])
df_metheo_core.dtypes
# Out:
# /tmp/ipykernel_15129/4052188590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_metheo_core['date'] = pd.to_datetime(df_metheo_core['date'])
# Address                      object
# Latitude                     object
# Longitude                    object
# Elevation                    object
# Local Date & Time            object
# Stellar Magnitude            object
# Color                        object
# state                        object
# white                          bool
# red                            bool
# blue                           bool
# green                          bool
# purple                         bool
# orange                         bool
# yellow                         bool
# date                 datetime64[ns]
# time                         object
# dtype: object

# %%
df_metheo_core = df_metheo_core[['date', 'time','Address', 'state','Latitude', 'Longitude', 'Elevation', 'Stellar Magnitude', 'white', 'red', 'blue', 'green', 'purple', 'orange', 'yellow']]

# %%
df_metheo_core = df_metheo_core.sort_values(by = 'date', ascending = True).reset_index(drop=True)
df_metheo_core
# Out:
#             date   time          Address state Latitude Longitude Elevation  \
# 0     1995-06-08  02:00    Trafalgar, IN    IN       39       -86       267
# 1     1995-06-20  17:00      Munhall, PA    PA       40       -79       329
# 2     1995-07-04  21:30       Myrtle, MS    MS       34       -89       108
# 3     1995-08-01  16:00    Pottstown, PA    PA       40       -75        46
# 4     1995-12-15  06:50        Eagan, MN    MN       44       -93       257
# ...          ...    ...              ...   ...      ...       ...       ...
# 11003 2014-12-31  22:40             , NY    NY       40       -73        28
# 11004 2014-12-31  21:30  Willow Hill, IL    IL       39       -87       151
# 11005 2014-12-31  22:34      fishers, IN    IN       39       -86         -
# 11006 2014-12-31  05:34       Denver, CO    CO       39      -105         -
# 11007 2014-12-31  19:12    Massillon, OH    OH       40       -81       310
#
#       Stellar Magnitude  white    red   blue  green  purple  orange  yellow
# 0                   -13  False  False  False   True   False   False   False
# 1                   -13  False   True  False  False   False    True   False
# 2                   -19  False   True  False  False   False    True    True
# 3                   -16  False   True  False  False   False   False   False
# 4                   -15   True  False  False  False   False   False   False
# ...                 ...    ...    ...    ...    ...     ...     ...     ...
# 11003               -14  False  False  False  False   False    True   False
# 11004               -18   True  False  False  False   False   False   False
# 11005               -11   True  False  False  False   False   False   False
# 11006                -6   True  False  False  False   False   False   False
# 11007               -14  False  False  False  False   False   False    True
#
# [11008 rows x 15 columns]

# %%
df_metheo_core['state'] = df_metheo_core['state'].str.replace(' ','')

# %%
df_metheo_core = df_metheo_core.loc[df_metheo_core['Elevation'] != '-']

# %%
df_metheo_core = df_metheo_core.reset_index(drop=True)

# %%
df_metheo_core
# Out:
#            date   time          Address state Latitude Longitude Elevation  \
# 0    1995-06-08  02:00    Trafalgar, IN    IN       39       -86       267
# 1    1995-06-20  17:00      Munhall, PA    PA       40       -79       329
# 2    1995-07-04  21:30       Myrtle, MS    MS       34       -89       108
# 3    1995-08-01  16:00    Pottstown, PA    PA       40       -75        46
# 4    1995-12-15  06:50        Eagan, MN    MN       44       -93       257
# ...         ...    ...              ...   ...      ...       ...       ...
# 7489 2014-12-31  02:08    Depoe Bay, OR    OR       44      -124        12
# 7490 2014-12-31  22:20             , OH    OH       39       -83       309
# 7491 2014-12-31  22:40             , NY    NY       40       -73        28
# 7492 2014-12-31  21:30  Willow Hill, IL    IL       39       -87       151
# 7493 2014-12-31  19:12    Massillon, OH    OH       40       -81       310
#
#      Stellar Magnitude  white    red   blue  green  purple  orange  yellow
# 0                  -13  False  False  False   True   False   False   False
# 1                  -13  False   True  False  False   False    True   False
# 2                  -19  False   True  False  False   False    True    True
# 3                  -16  False   True  False  False   False   False   False
# 4                  -15   True  False  False  False   False   False   False
# ...                ...    ...    ...    ...    ...     ...     ...     ...
# 7489                -6   True  False  False  False   False   False   False
# 7490               -11  False  False  False  False   False   False    True
# 7491               -14  False  False  False  False   False    True   False
# 7492               -18   True  False  False  False   False   False   False
# 7493               -14  False  False  False  False   False   False    True
#
# [7494 rows x 15 columns]

# %% [markdown]
# #### 데이터 베이스 저장

# %%
import mysql.connector
import os
from dotenv import load_dotenv
from mysql.connector import Error

# %%
load_dotenv()
aws_db_ufo_pw = os.getenv('aws_db_ufo_pw')
aws_host_ufo = os.getenv('aws_host_ufo')

# %%
remote = mysql.connector.connect(
    host = aws_host_ufo,
    user = 'EDA',
    port = 3306,  # default 는 3306
    password = aws_db_ufo_pw,
    database = 'Frisbee'

)

cursor = remote.cursor()

# %%
cursor.close()
# Out:
# True

# %%
df_metheo_core
# Out:
#            date   time          Address state Latitude Longitude Elevation  \
# 0    1995-06-08  02:00    Trafalgar, IN    IN       39       -86       267
# 1    1995-06-20  17:00      Munhall, PA    PA       40       -79       329
# 2    1995-07-04  21:30       Myrtle, MS    MS       34       -89       108
# 3    1995-08-01  16:00    Pottstown, PA    PA       40       -75        46
# 4    1995-12-15  06:50        Eagan, MN    MN       44       -93       257
# ...         ...    ...              ...   ...      ...       ...       ...
# 7489 2014-12-31  02:08    Depoe Bay, OR    OR       44      -124        12
# 7490 2014-12-31  22:20             , OH    OH       39       -83       309
# 7491 2014-12-31  22:40             , NY    NY       40       -73        28
# 7492 2014-12-31  21:30  Willow Hill, IL    IL       39       -87       151
# 7493 2014-12-31  19:12    Massillon, OH    OH       40       -81       310
#
#      Stellar Magnitude  white    red   blue  green  purple  orange  yellow
# 0                  -13  False  False  False   True   False   False   False
# 1                  -13  False   True  False  False   False    True   False
# 2                  -19  False   True  False  False   False    True    True
# 3                  -16  False   True  False  False   False   False   False
# 4                  -15   True  False  False  False   False   False   False
# ...                ...    ...    ...    ...    ...     ...     ...     ...
# 7489                -6   True  False  False  False   False   False   False
# 7490               -11  False  False  False  False   False   False    True
# 7491               -14  False  False  False  False   False    True   False
# 7492               -18   True  False  False  False   False   False   False
# 7493               -14  False  False  False  False   False   False    True
#
# [7494 rows x 15 columns]

# %%
table_name = 'metheo'

query_create_table = f"""
        CREATE TABLE IF NOT EXISTS {table_name} (
            id INT AUTO_INCREMENT PRIMARY KEY,
            date DATETIME,
            time TIME,
            address CHAR(25),
            state CHAR(4),
            latitude INT,
            longitude INT,
            elevation INT,
            magnitude INT,
            white BOOL,
            red BOOL,
            blue BOOL,
            green BOOL,
            purple BOOL,
            orange BOOL,
            yellow BOOL
            )
        """
        
        
cursor.execute(query_create_table)
remote.commit()
print(f"테이블 '{table_name}'이(가) 성공적으로 생성되었거나 이미 존재합니다.")
# Out:
# 테이블 'metheo'이(가) 성공적으로 생성되었거나 이미 존재합니다.

# %%
for idx, row in df_metheo_core.iterrows():

    query = f"""
    INSERT INTO {table_name} (date, time, address, state, latitude, longitude, elevation, magnitude,white,red, blue, green, purple, orange, yellow)
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    """

    cursor.execute(query, tuple(row))
    
    
remote.commit()
print(f"{cursor.rowcount} 개의 ROW가 {table_name} 테이블에 성공적으로 삽입 되었습니다")
# Out:
# 1 개의 ROW가 metheo 테이블에 성공적으로 삽입 되었습니다

# %%
df_sw_core.to_csv('/home/roni/dev_ws/ufo_eda/data/metheo_core.csv')
